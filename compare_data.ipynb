# %%
import pandas as pd
import matplotlib.pyplot as plt
mfc2 = ['tab:orange', 'tab:blue', 'tab:green', 'tab:red', 'tab:purple']

# %%
df1 = pd.read_csv('compare_data_with_out_eNRTL.csv')
df2 = pd.read_csv('compare_data_with_eNRTL.csv')
T_range = df2['temperature'].unique()

# display(df2)
plt.figure(figsize=(8,8))
for i, T in enumerate(T_range):
    df_cut_1 = df1[df1['temperature']==T]
    df_cut_2 = df2[df2['temperature']==T]

    plt.plot(df_cut_1['loading'].to_numpy(), df_cut_1['fug_CO2'].to_numpy(),
             'x', label=f'T = {T}: Without eNRTL', color=mfc2[i])
    plt.plot(df_cut_2['loading'].to_numpy(), df_cut_2['fug_CO2'].to_numpy(),
             label=f'T = {T}: With eNRTL', color=mfc2[i])
    plt.legend()
    plt.xlabel("CO$_{2}$ Loading, mol CO$_{2}$/mol MEA")
    plt.ylabel("CO$_{2}$ pressure, kPa")
    plt.yscale('log')
plt.show()

# %%
df1 = pd.read_csv('compare_data_with_out_eNRTL.csv')
df2 = pd.read_csv('compare_data_with_eNRTL.csv')
T_range = df2['temperature'].unique()

# display(df2)
plt.figure(figsize=(8,8))
for i, T in enumerate(T_range):
    df_cut_1 = df1[df1['temperature']==T]
    df_cut_2 = df2[df2['temperature']==T]

    plt.plot(df_cut_1['loading'].to_numpy(), df_cut_1['Pressure'].to_numpy(),
             'x', label=f'T = {T}: Without eNRTL', color=mfc2[i])
    plt.plot(df_cut_2['loading'].to_numpy(), df_cut_2['Pressure'].to_numpy(),
             label=f'T = {T}: With eNRTL', color=mfc2[i])
    plt.legend()
    plt.xlabel("CO$_{2}$ Loading, mol CO$_{2}$/mol MEA")
    plt.ylabel("CO$_{2}$ pressure, kPa")
    plt.yscale('log')
plt.show()

# %%
df1 = pd.read_csv('compare_data_with_out_eNRTL.csv')
df2 = pd.read_csv('compare_data_with_eNRTL.csv')
T_range = df2['temperature'].unique()

# display(df2)
plt.figure(figsize=(8,8))
y_key = 'act_coeff_CO2'
for i, T in enumerate(T_range):
    df_cut_1 = df1[df1['temperature']==T]
    df_cut_2 = df2[df2['temperature']==T]

    plt.plot(df_cut_1['loading'].to_numpy(), df_cut_1[y_key].to_numpy(),
             'x', label=f'T = {T}: Without eNRTL', color=mfc2[i])
    plt.plot(df_cut_2['loading'].to_numpy(), df_cut_2[y_key].to_numpy(),
             label=f'T = {T}: With eNRTL', color=mfc2[i])
    plt.legend()
    plt.xlabel("CO$_{2}$ Loading, mol CO$_{2}$/mol MEA")
    # plt.ylabel("CO$_{2}$ pressure, kPa")
    # plt.yscale('log')
plt.show()

# %%
df1 = pd.read_csv('compare_data_with_out_eNRTL.csv')
df2 = pd.read_csv('compare_data_with_eNRTL.csv')
T_range = df2['temperature'].unique()

# display(df2)
plt.figure(figsize=(8,8))
y_key = 'Henry_CO2'
for i, T in enumerate(T_range):
    df_cut_1 = df1[df1['temperature']==T]
    df_cut_2 = df2[df2['temperature']==T]

    plt.plot(df_cut_1['loading'].to_numpy(), df_cut_1[y_key].to_numpy(),
             'x', label=f'T = {T}: Without eNRTL', color=mfc2[i])
    plt.plot(df_cut_2['loading'].to_numpy(), df_cut_2[y_key].to_numpy(),
             label=f'T = {T}: With eNRTL', color=mfc2[i])
    plt.legend()
    plt.xlabel("CO$_{2}$ Loading, mol CO$_{2}$/mol MEA")
    plt.ylabel("CO$_{2}$ Henry pressure, kPa")
    plt.yscale('log')
plt.show()

# %%
df1 = pd.read_csv('compare_data_with_out_eNRTL.csv')
df2 = pd.read_csv('compare_data_with_eNRTL.csv')
T_range = df2['temperature'].unique()

# display(df2)
plt.figure(figsize=(8,8))
y_key = 'x_CO2'
for i, T in enumerate(T_range):
    df_cut_1 = df1[df1['temperature']==T]
    df_cut_2 = df2[df2['temperature']==T]

    plt.plot(df_cut_1['loading'].to_numpy(), df_cut_1[y_key].to_numpy(),
             'x', label=f'T = {T}: Without eNRTL', color=mfc2[i])
    plt.plot(df_cut_2['loading'].to_numpy(), df_cut_2[y_key].to_numpy(),
             label=f'T = {T}: With eNRTL', color=mfc2[i])
    plt.legend()
    plt.xlabel("CO$_{2}$ Loading, mol CO$_{2}$/mol MEA")
    plt.ylabel("$x_{CO_2}$")
    plt.yscale('log')
plt.show()
